# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=31e14bdb02f7ad309ec885dc97078c31&language=en-US&page=1')

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 100.059,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 16678},
#  {'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg          [18, 80]     238
# 1   False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg          [18, 80]     278
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4   False  /vI3aUGTuRRdM7J78KIdW98LdxE5.jpg   [35, 18, 10749]   19404
# 5   False  /bxSBOAD8AuMHYMdW3jso9npAkgt.jpg       [10751, 18]  667257
# 6   False  /Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg   [16, 10751, 14]     129
# 7   False  /mMtUybQ6hL24FXo0F3Z4j2KG7kZ.jpg   [10749, 16, 18]  372058
# 8   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg              [18]     389
# 9   False   /TU9NIjwzjoKPwQHoHshkFcQUCG.jpg      [35, 53, 18]  496243
# 10  False  /jtAI6OJIWLWiRItNSZoWjrsUtmi.jpg           [10749]  724089
# 11  False  /l6hQWH9eDksNJNiXWYRkWqikOdu.jpg      [14, 18, 80]     497
# ...

# %%
pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg  [18, 80]  238                en
# 1  False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg  [18, 80]  278                en
#
#              original_title  \
# 0             The Godfather
# 1  The Shawshank Redemption
#
#                                             overview  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...     100.059
# 1  Framed in the 1940s for the double murder of h...      79.819
#
#                         poster_path release_date                     title  \
# 0  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
# 1  /q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg   1994-09-23  The Shawshank Redemption
#
#    video  vote_average  vote_count
# 0  False           8.7       16678
# 1  False           8.7       22400

# %%
pd.DataFrame(response.json()['results']).head(2)[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count' ]]
# Out:
#     id                     title  \
# 0  238             The Godfather
# 1  278  The Shawshank Redemption
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     100.059
# 1  Framed in the 1940s for the double murder of h...   1994-09-23      79.819
#
#    vote_average  vote_count
# 0           8.7       16678
# 1           8.7       22400

# %%
df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count' ]]

# %%
df.head()
# Out:
#       id                        title  \
# 0    238                The Godfather
# 1    278     The Shawshank Redemption
# 2    240        The Godfather Part II
# 3    424             Schindler's List
# 4  19404  Dilwale Dulhania Le Jayenge
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     100.059
# 1  Framed in the 1940s for the double murder of h...   1994-09-23      79.819
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      57.346
# 3  The true story of how businessman Oskar Schind...   1993-12-15      63.760
# 4  Raj is a rich, carefree, happy-go-lucky second...   1995-10-19      28.101
#
#    vote_average  vote_count
# 0           8.7       16678
# 1           8.7       22400
# 2           8.6       10092
# 3           8.6       13281
# 4           8.6        3892

# %%
df = pd.DataFrame()

# %%
for i in range (1, 518):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=31e14bdb02f7ad309ec885dc97078c31&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count' ]]
    df = df.append(temp_df, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-f0780c87ce57> in <module>
#       1 for i in range (1, 518):
#       2     response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=31e14bdb02f7ad309ec885dc97078c31&language=en-US&page={}'.format(i))
# ----> 3     temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count' ]]
#       4     df = df.append(temp_df, ignore_index=True)
#
# KeyError: 'results'

# %%
df
# Out:
#            id                        title  \
# 0         238                The Godfather
# 1         278     The Shawshank Redemption
# 2         240        The Godfather Part II
# 3         424             Schindler's List
# 4       19404  Dilwale Dulhania Le Jayenge
# ...       ...                          ...
# 48323  301608                    The Trust
# 48324    3093             Basic Instinct 2
# 48325   11090                   The Animal
# 48326  429422                       Capone
# 48327  206821             The Longest Week
#
#                                                 overview release_date  \
# 0      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1      Framed in the 1940s for the double murder of h...   1994-09-23
# 2      In the continuing saga of the Corleone crime f...   1974-12-20
# 3      The true story of how businessman Oskar Schind...   1993-12-15
# 4      Raj is a rich, carefree, happy-go-lucky second...   1995-10-19
# ...

# %%
df.shape
# Out:
# (38328, 7)
